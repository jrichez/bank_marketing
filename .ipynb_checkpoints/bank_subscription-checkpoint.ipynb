# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('bank-additional-full.csv', sep=';')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.y.value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
#  Some basics observations :
#
# > The goal is to predict if a person will suscribed (feature : y)
#
# > It's a binary classification
#
# > We have 21 features
#
# > No missing values
#
# > The class to predict is pretty imbalanced
#
# > We have numerical and categorical variables

# %%
"""
EDA 
Outliers
Encoder
Split
Baseline model 
Feature engineering
Model
Hyperparameter tuning
"""
# Out:
# '\nEDA \nOutliers\nEncoder\nSplit\nBaseline model \nFeature engineering\nModel\nHyperparameter tuning\n'

# %% [markdown]
# ## EDA

# %%
var_num = df.select_dtypes(include=['float64', 'int64'])
var_cat = df.select_dtypes(exclude=['float64', 'int64'])

# %%
c = 1 
nrows = round(len(var_num.columns) / 3) + 1
fig = plt.figure(figsize=(15,13))
for i in var_num.columns:
    plt.subplot(nrows, 3, c)
    sns.histplot(x=i, hue='y', data=df)
    c += 1 
plt.show()

# %% [markdown]
# ### Age

# %%
sns.histplot(x='age', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# Let's cut the values of age in marketing segment

# %%
labels = ['0-3', '4-8', '9-12', '13-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '+85']
bins = [0, 3, 8, 12, 17, 24, 34, 44, 54, 64, 74, 84, 120]
df["age_bins"] = pd.Categorical(pd.cut(df.age, bins, labels=labels), categories=labels, ordered=True)

# %%
plt.figure(figsize=(12,4))
sns.histplot(x='age_bins', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='age_bins', ylabel='Count'>

# %%
age_grouped = df.groupby(['age_bins', 'y'])['y'].count()
age_per = age_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

# %%
age_per.filter(like='yes').sort_values(ascending=False)
# Out:
# age_bins  y
# 75-84     yes    52.606635
# +85       yes    50.000000
# 65-74     yes    43.908629
# 13-17     yes    40.000000
# 18-24     yes    23.894638
# 55-64     yes    13.568825
# 25-34     yes    12.173024
# 35-44     yes     8.651852
# 45-54     yes     8.651195
# 0-3       yes          NaN
# 4-8       yes          NaN
# 9-12      yes          NaN
# Name: y, dtype: float64

# %% [markdown]
# > Here we can see the proportion of each category of age with the corresponding percentage of subscriptions
#
# > The old persons seem to be more inclined to subscribed (these numbers should be taken with a grain of salt due to the low volume of observations on these categories)

# %% [markdown]
# ### Campaign

# %% [markdown]
# According to the data description, the feature correspond to the number of times a client has been contacted for this campaign

# %%
sns.catplot('campaign', 'y', data=df)
# Out:
# C:\Users\riche\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > We can see that people who get a subscription do it before the 15th contacts. In most cases, the client get the subscription before the 10th contact
#
# > It doesn't seems to be useful to contact a person much more than 10 times

# %%
c = 1 
nrows = round(len(var_cat.columns) / 3) + 1
fig = plt.figure(figsize=(15,17))
for i in var_cat.columns:
    plt.subplot(nrows, 3, c)
    sns.histplot(x=i, hue='y', data=df)
    c += 1 
plt.show()

# %% [markdown]
# ### Poutcome

# %% [markdown]
# According to the data description, the feature indicates if the client subscribed on the last campaign

# %%
sns.histplot(x='poutcome', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='poutcome', ylabel='Count'>

# %%
poutcome_grouped = df.groupby(['poutcome', 'y'])['y'].count()

# %%
poutcome_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
# Out:
# poutcome     y
# failure      no     85.771402
#              yes    14.228598
# nonexistent  no     91.167787
#              yes     8.832213
# success      no     34.887109
#              yes    65.112891
# Name: y, dtype: float64

# %% [markdown]
# > Here we clearly see that the percentage of subscription is much more high if the result of the previous campaign was a success
#
# > Unfortunately the volume of this category is insufficient to make proper conclusions

# %% [markdown]
# ### Month

# %%
df['month'] = pd.Categorical(df['month'], categories=['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'],
                                   ordered=True)

# %%
sns.histplot(x='month', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Count'>

# %% [markdown]
# > The campaign begun in march with the highest number of contacts in may
#
# > The number of subscription seems to be regular during all the year, except at the begin and the end of the campaign
#
# > The number of subscriptions doesn't seems to be proportional at the number of contacts and tend to a have a maximum of volume

# %% [markdown]
# ### Day of the week

# %%
sns.histplot(x='day_of_week', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='Count'>

# %% [markdown]
# > The number of contacts and subscriptions is regular
#
# > It doesn't seems to have a better day to contact the potential subscribers

# %% [markdown]
# ### Job

# %%
plt.figure(figsize=(17,5))
sns.histplot(x='job', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='job', ylabel='Count'>

# %%
poutcome_grouped = df.groupby(['job', 'y'])['y'].count()
poutcome_per = poutcome_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

# %%
poutcome_per.filter(like='yes').sort_values(ascending=False)
# Out:
# job            y
# student        yes    31.428571
# retired        yes    25.232558
# unemployed     yes    14.201183
# admin.         yes    12.972558
# management     yes    11.217510
# unknown        yes    11.212121
# technician     yes    10.826042
# self-employed  yes    10.485574
# housemaid      yes    10.000000
# entrepreneur   yes     8.516484
# services       yes     8.138070
# blue-collar    yes     6.894316
# Name: y, dtype: float64

# %% [markdown]
# > Here we can see the proportion of each category of job with the corresponding percentage of subscriptions
#
# > The two categories most inclined to sub are student and retired

# %% [markdown]
# ### Education

# %%
plt.figure(figsize=(17,5))
sns.histplot(x='education', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='Count'>

# %%
education_grouped = df.groupby(['education', 'y'])['y'].count()
education_per = education_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

# %%
education_per.filter(like='yes').sort_values(ascending=False)
# Out:
# education            y
# illiterate           yes    22.222222
# unknown              yes    14.500289
# university.degree    yes    13.724523
# professional.course  yes    11.348465
# high.school          yes    10.835523
# basic.4y             yes    10.249042
# basic.6y             yes     8.202443
# basic.9y             yes     7.824648
# Name: y, dtype: float64

# %% [markdown]
# > According to the data, the illiterate category is more inclined to subscribe (we can nuance this result by the low volume of observations in this category)
#
# > The percentage of subs is lower in basics categories

# %% [markdown]
# ### Marital

# %%
sns.histplot(x='marital', hue='y', data=df)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='Count'>

# %%
marital_grouped = df.groupby(['marital', 'y'])['y'].count()
marital_per = marital_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

# %%
marital_per.filter(like='yes').sort_values(ascending=False)
# Out:
# marital   y
# unknown   yes    15.000000
# single    yes    14.004149
# divorced  yes    10.320902
# married   yes    10.157253
# Name: y, dtype: float64

# %% [markdown]
# > The singles seems to be a little bit more interested in the subscription

# %% [markdown]
# ### Outliers

# %%
c = 1 
nrows = round(len(var_num.columns) / 3) + 1
fig = plt.figure(figsize=(17,10))
for i in var_num.columns:
    plt.subplot(nrows, 3, c)
    sns.boxplot(x=i, hue='y', data=df)
    c += 1 
plt.tight_layout()
plt.show()

# %% [markdown]
# I can identify some outliers which can make the model perform worse
#
# Let's get rid of it

# %%
df[df['campaign'] > 50]
# Out:
#       age     job  marital          education  default  housing     loan  \
# 4107   32  admin.  married  university.degree  unknown  unknown  unknown
#
#         contact month day_of_week  ...  pdays  previous     poutcome  \
# 4107  telephone   may         mon  ...    999         0  nonexistent
#
#       emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 4107           1.1         93.994          -36.4      4.858       5191.0  no
#
#       age_bins
# 4107     25-34
#
# [1 rows x 22 columns]

# %%
df.drop(4107, inplace=True)

# %%
idx_to_drop = df[df['cons.conf.idx'] > -27].index

# %%
df.drop(idx_to_drop, inplace=True)

# %%
df.shape
# Out:
# (40740, 22)

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# The column 'age_bins' was for the purpose oh the analysis, we can now delete it

# %%
df.drop('age_bins', axis=1, inplace=True)

# %% [markdown]
# ### Encode

# %%
le = LabelEncoder()
df['y'] = le.fit_transform(df['y'])

# %%
for i in var_cat.columns:
    print(str(i) + ' : ' + str(var_cat[i].nunique()))
# Out:
# job : 12
# marital : 4
# education : 8
# default : 3
# housing : 3
# loan : 3
# contact : 2
# month : 10
# day_of_week : 5
# poutcome : 3
# y : 2

# %% [markdown]
# We have low cardinality for categorical variables so we can apply one hot encoding

# %%
df = pd.get_dummies(df)

# %% [markdown]
# ### Split

# %%
df.drop('duration', axis=1, inplace=True)

# %%
X = df.copy()
y = X.pop('y')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=6)

# %% [markdown]
# ### Balance

# %% [markdown]
# I now have to take care of the high imbalanced target
#
# I'll use Smote which is an over sampling method based on k nearest neighbors

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\riche\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\riche\anaconda3\lib\site-packages (from imbalanced-learn) (1.19.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\riche\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\riche\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\riche\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\riche\appdata\roaming\python\python38\site-packages (from imbalanced-learn) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()

# %%
X_train, y_train = oversample.fit_resample(X_train, y_train)
X_test, y_test = oversample.fit_resample(X_test, y_test)

# %% [markdown]
# ### Scale

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\riche\anaconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: scipy in c:\users\riche\anaconda3\lib\site-packages (from catboost) (1.5.4)
# Requirement already satisfied: plotly in c:\users\riche\anaconda3\lib\site-packages (from catboost) (5.5.0)
# Requirement already satisfied: graphviz in c:\users\riche\anaconda3\lib\site-packages (from catboost) (0.19.1)
# Requirement already satisfied: matplotlib in c:\users\riche\anaconda3\lib\site-packages (from catboost) (3.4.2)
# Requirement already satisfied: six in c:\users\riche\anaconda3\lib\site-packages (from catboost) (1.15.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\riche\anaconda3\lib\site-packages (from catboost) (1.19.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\riche\appdata\roaming\python\python38\site-packages (from catboost) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\riche\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\riche\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2021.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\riche\anaconda3\lib\site-packages (from matplotlib->catboost) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\riche\anaconda3\lib\site-packages (from matplotlib->catboost) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\riche\anaconda3\lib\site-packages (from matplotlib->catboost) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\riche\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\riche\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, recall_score

# %% [markdown]
# According to our goal, we'll look at first at the recall as metrics.
#
# Indeed we want to avoid the false negatives which are for this campaign a missed opportunity.

# %%
estimators = [LogisticRegression(),
             RandomForestClassifier(),
             XGBClassifier(),
             LGBMClassifier(),
             CatBoostClassifier(verbose=0)]

# %%
for i in estimators:
    i.fit(X_train, y_train)
    y_pred = i.predict(X_test)
    print(str(i) + ':\n' + str(classification_report(y_test, y_pred)))
# Out:
# C:\Users\riche\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      9070
#            1       0.98      0.91      0.94      9070
#
#     accuracy                           0.94     18140
#    macro avg       0.95      0.94      0.94     18140
# weighted avg       0.95      0.94      0.94     18140
#
# RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      9070
#            1       0.96      0.88      0.91      9070
#
#     accuracy                           0.92     18140
#    macro avg       0.92      0.92      0.92     18140
# weighted avg       0.92      0.92      0.92     18140
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      9070
#            1       0.97      0.91      0.94      9070
#
#     accuracy                           0.94     18140
#    macro avg       0.94      0.94      0.94     18140
# weighted avg       0.94      0.94      0.94     18140
#
# LGBMClassifier():
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      9070
#            1       0.97      0.91      0.94      9070
#
#     accuracy                           0.94     18140
#    macro avg       0.95      0.94      0.94     18140
# weighted avg       0.95      0.94      0.94     18140
#
# <catboost.core.CatBoostClassifier object at 0x00000262089D94F0>:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      9070
#            1       0.97      0.91      0.94      9070
#
#     accuracy                           0.94     18140
#    macro avg       0.94      0.94      0.94     18140
# weighted avg       0.94      0.94      0.94     18140

# %% [markdown]
# The best result (recall score and accuracy) come with the light gbm classifier
#
# I'll pursue with it

# %% [markdown]
# ### Hyperparamer tuning

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\riche\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: colorlog in c:\users\riche\anaconda3\lib\site-packages (from optuna) (6.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in c:\users\riche\anaconda3\lib\site-packages (from optuna) (0.8.2)
# Requirement already satisfied: alembic in c:\users\riche\anaconda3\lib\site-packages (from optuna) (1.7.5)
# Requirement already satisfied: tqdm in c:\users\riche\appdata\roaming\python\python38\site-packages (from optuna) (4.56.0)
# Requirement already satisfied: scipy!=1.4.0 in c:\users\riche\anaconda3\lib\site-packages (from optuna) (1.5.4)
# Requirement already satisfied: cliff in c:\users\riche\anaconda3\lib\site-packages (from optuna) (3.10.0)
# Requirement already satisfied: PyYAML in c:\users\riche\appdata\roaming\python\python38\site-packages (from optuna) (5.3.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in c:\users\riche\anaconda3\lib\site-packages (from optuna) (1.4.22)
# Requirement already satisfied: packaging>=20.0 in c:\users\riche\anaconda3\lib\site-packages (from optuna) (21.0)
# Requirement already satisfied: numpy in c:\users\riche\anaconda3\lib\site-packages (from optuna) (1.19.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\riche\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\riche\anaconda3\lib\site-packages (from sqlalchemy>=1.1.0->optuna) (1.1.1)
# Requirement already satisfied: Mako in c:\users\riche\anaconda3\lib\site-packages (from alembic->optuna) (1.1.6)
# Requirement already satisfied: importlib-resources in c:\users\riche\anaconda3\lib\site-packages (from alembic->optuna) (5.4.0)
# Requirement already satisfied: importlib-metadata in c:\users\riche\anaconda3\lib\site-packages (from alembic->optuna) (4.8.1)
# Requirement already satisfied: autopage>=0.4.0 in c:\users\riche\anaconda3\lib\site-packages (from cliff->optuna) (0.4.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in c:\users\riche\anaconda3\lib\site-packages (from cliff->optuna) (3.0.0)
# Requirement already satisfied: stevedore>=2.0.1 in c:\users\riche\anaconda3\lib\site-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\riche\anaconda3\lib\site-packages (from cliff->optuna) (5.8.0)
# Requirement already satisfied: cmd2>=1.0.0 in c:\users\riche\anaconda3\lib\site-packages (from cliff->optuna) (2.3.3)
# Requirement already satisfied: wcwidth>=0.1.7 in c:\users\riche\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in c:\users\riche\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in c:\users\riche\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (21.2.0)
# Requirement already satisfied: pyreadline3 in c:\users\riche\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (3.3)
# Requirement already satisfied: colorama in c:\users\riche\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\riche\anaconda3\lib\site-packages (from importlib-metadata->alembic->optuna) (3.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\riche\anaconda3\lib\site-packages (from Mako->alembic->optuna) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
from optuna.samplers import TPESampler

# %%
def objective(trial):
    param = {
        "objective": "binary",
        "verbosity": -1,
        "boosting_type": "gbdt",                
        "seed": 42,
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 1.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 1.0),
        'num_leaves': trial.suggest_int('num_leaves', 2, 512),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    
    classifier = LGBMClassifier(**param)
    classifier.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=0)
    y_pred = classifier.predict(X_test)  
    score = recall_score(y_test, y_pred)        
    return score

# %%
study = optuna.create_study(sampler=TPESampler(), direction="maximize")
study.optimize(objective, n_trials=10000, timeout=1800) # Run for 30 minutes     
print("Number of completed trials: {}".format(len(study.trials)))   
print("Best trial:")
trial = study.best_trial      
     
print("\tBest Score: {}".format(trial.value))                                                                 
print("\tBest Params: ")           
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2022-01-14 13:11:51,800] A new study created in memory with name: no-name-cbe947fb-40b8-422a-90ce-436448bc53b6
# [I 2022-01-14 13:11:54,583] Trial 0 finished with value: 0.9038588754134509 and parameters: {'lambda_l1': 8.084183941755323e-05, 'lambda_l2': 1.2098706396514047e-06, 'num_leaves': 427, 'feature_fraction': 0.8510690196703834, 'bagging_fraction': 0.8237492839215772, 'bagging_freq': 2, 'min_child_samples': 29}. Best is trial 0 with value: 0.9038588754134509.
# [I 2022-01-14 13:11:56,086] Trial 1 finished with value: 0.9013230429988974 and parameters: {'lambda_l1': 0.04685128664338508, 'lambda_l2': 1.5235893860040538e-06, 'num_leaves': 297, 'feature_fraction': 0.3374904537042963, 'bagging_fraction': 0.6734214948176308, 'bagging_freq': 3, 'min_child_samples': 29}. Best is trial 0 with value: 0.9038588754134509.
# [I 2022-01-14 13:11:57,132] Trial 2 finished with value: 0.9076074972436604 and parameters: {'lambda_l1': 1.3503372790980939e-05, 'lambda_l2': 0.0019825386040315768, 'num_leaves': 65, 'feature_fraction': 0.8071254823750881, 'bagging_fraction': 0.5843830862479167, 'bagging_freq': 12, 'min_child_samples': 47}. Best is trial 2 with value: 0.9076074972436604.
# [I 2022-01-14 13:11:58,873] Trial 3 finished with value: 0.9022050716648291 and parameters: {'lambda_l1': 2.9115723622666475e-08, 'lambda_l2': 2.28608639819447e-08, 'num_leaves': 431, 'feature_fraction': 0.4025196783588786, 'bagging_fraction': 0.3813694677790407, 'bagging_freq': 13, 'min_child_samples': 43}. Best is trial 2 with value: 0.9076074972436604.
# [I 2022-01-14 13:11:59,958] Trial 4 finished with value: 0.9058434399117972 and parameters: {'lambda_l1': 3.540355087960563e-05, 'lambda_l2': 0.3106976638527763, 'num_leaves': 36, 'feature_fraction': 0.6230218838185859, 'bagging_fraction': 0.8637897629565275, 'bagging_freq': 4, 'min_child_samples': 69}. Best is trial 2 with value: 0.9076074972436604.
# [I 2022-01-14 13:12:01,703] Trial 5 finished with value: 0.907497243660419 and parameters: {'lambda_l1': 0.00132110789247464, 'lambda_l2': 2.47192347752315e-06, 'num_leaves': 218, 'feature_fraction': 0.9239522596778453, 'bagging_fraction': 0.6092923144781242, 'bagging_freq': 10, 'min_child_samples': 14}. Best is trial 2 with value: 0.9076074972436604.
# [I 2022-01-14 13:12:03,039] Trial 6 finished with value: 0.9098125689084895 and parameters: {'lambda_l1': 5.7151879199570914e-08, 'lambda_l2': 0.08186747638111969, 'num_leaves': 75, 'feature_fraction': 0.8336001296462938, 'bagging_fraction': 0.6317125723044039, 'bagging_freq': 0, 'min_child_samples': 53}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:04,760] Trial 7 finished with value: 0.8998897464167586 and parameters: {'lambda_l1': 6.444083496309513e-06, 'lambda_l2': 4.2204899767254666e-07, 'num_leaves': 449, 'feature_fraction': 0.5244680602228158, 'bagging_fraction': 0.3660455483145584, 'bagging_freq': 14, 'min_child_samples': 34}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:05,423] Trial 8 finished with value: 0.9059536934950386 and parameters: {'lambda_l1': 0.001598473060341302, 'lambda_l2': 2.5829263176788583e-06, 'num_leaves': 15, 'feature_fraction': 0.21621285626650744, 'bagging_fraction': 0.8968973891676622, 'bagging_freq': 2, 'min_child_samples': 97}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:06,586] Trial 9 finished with value: 0.9091510474090408 and parameters: {'lambda_l1': 1.1869616698790945e-07, 'lambda_l2': 0.20087716108969042, 'num_leaves': 105, 'feature_fraction': 0.713888288193642, 'bagging_fraction': 0.6254611224197583, 'bagging_freq': 0, 'min_child_samples': 45}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:07,557] Trial 10 finished with value: 0.9065049614112458 and parameters: {'lambda_l1': 3.2279041138873307e-07, 'lambda_l2': 0.0019638118106346824, 'num_leaves': 173, 'feature_fraction': 0.9895014028096261, 'bagging_fraction': 0.1800907871265932, 'bagging_freq': 7, 'min_child_samples': 72}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:08,896] Trial 11 finished with value: 0.9039691289966924 and parameters: {'lambda_l1': 5.735953335304749e-08, 'lambda_l2': 0.7043109581517456, 'num_leaves': 139, 'feature_fraction': 0.6995187703877439, 'bagging_fraction': 0.44197658020426717, 'bagging_freq': 0, 'min_child_samples': 65}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:10,281] Trial 12 finished with value: 0.9057331863285557 and parameters: {'lambda_l1': 6.784349475756731e-07, 'lambda_l2': 0.020955710995205032, 'num_leaves': 121, 'feature_fraction': 0.7412036978605334, 'bagging_fraction': 0.7513144186997852, 'bagging_freq': 6, 'min_child_samples': 2}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:11,969] Trial 13 finished with value: 0.8976846747519295 and parameters: {'lambda_l1': 4.792547019156649e-07, 'lambda_l2': 0.017102424239140893, 'num_leaves': 308, 'feature_fraction': 0.5486016609548706, 'bagging_fraction': 0.9831192602648475, 'bagging_freq': 0, 'min_child_samples': 58}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:13,227] Trial 14 finished with value: 0.9069459757442117 and parameters: {'lambda_l1': 1.035995248544434e-08, 'lambda_l2': 0.00010608860071598166, 'num_leaves': 88, 'feature_fraction': 0.7047107462153239, 'bagging_fraction': 0.5077232020322358, 'bagging_freq': 0, 'min_child_samples': 86}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:14,927] Trial 15 finished with value: 0.9081587651598677 and parameters: {'lambda_l1': 0.9866444325022113, 'lambda_l2': 0.06747205170413786, 'num_leaves': 234, 'feature_fraction': 0.8986031512857101, 'bagging_fraction': 0.7141359471705416, 'bagging_freq': 5, 'min_child_samples': 53}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:16,024] Trial 16 finished with value: 0.9039691289966924 and parameters: {'lambda_l1': 2.1295264837236056e-06, 'lambda_l2': 0.0009286041082972836, 'num_leaves': 161, 'feature_fraction': 0.6167907548735276, 'bagging_fraction': 0.2162002831380358, 'bagging_freq': 9, 'min_child_samples': 41}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:16,547] Trial 17 finished with value: 0.8988974641675854 and parameters: {'lambda_l1': 1.0618174658474114e-07, 'lambda_l2': 0.0719156058256976, 'num_leaves': 11, 'feature_fraction': 0.44095838498895124, 'bagging_fraction': 0.28810954053416177, 'bagging_freq': 2, 'min_child_samples': 84}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:18,463] Trial 18 finished with value: 0.9011025358324145 and parameters: {'lambda_l1': 0.001459043557718953, 'lambda_l2': 6.001069176114566e-05, 'num_leaves': 353, 'feature_fraction': 0.7943951530994433, 'bagging_fraction': 0.49857124237301254, 'bagging_freq': 4, 'min_child_samples': 19}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:19,190] Trial 19 finished with value: 0.9041896361631753 and parameters: {'lambda_l1': 1.0255898402814815e-08, 'lambda_l2': 0.6772519143398158, 'num_leaves': 86, 'feature_fraction': 0.1387365446244967, 'bagging_fraction': 0.6235172990786413, 'bagging_freq': 9, 'min_child_samples': 61}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:20,840] Trial 20 finished with value: 0.9038588754134509 and parameters: {'lambda_l1': 2.461559642633862e-06, 'lambda_l2': 9.98371605930972e-05, 'num_leaves': 196, 'feature_fraction': 0.6365399183668121, 'bagging_fraction': 0.7790511898088356, 'bagging_freq': 1, 'min_child_samples': 77}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:22,562] Trial 21 finished with value: 0.9067254685777287 and parameters: {'lambda_l1': 0.25758605521624817, 'lambda_l2': 0.023071840063284953, 'num_leaves': 245, 'feature_fraction': 0.9051402955949274, 'bagging_fraction': 0.7018050137651866, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:24,851] Trial 22 finished with value: 0.9051819184123484 and parameters: {'lambda_l1': 0.028961486975754538, 'lambda_l2': 0.12270314194797613, 'num_leaves': 505, 'feature_fraction': 0.9697546792742617, 'bagging_fraction': 0.6938590128186537, 'bagging_freq': 5, 'min_child_samples': 51}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:26,539] Trial 23 finished with value: 0.9051819184123484 and parameters: {'lambda_l1': 0.6848920613011648, 'lambda_l2': 0.0054279734552916455, 'num_leaves': 251, 'feature_fraction': 0.8389228601772928, 'bagging_fraction': 0.5452147889817622, 'bagging_freq': 4, 'min_child_samples': 37}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:27,965] Trial 24 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 0.00026349435661312794, 'lambda_l2': 0.10452802955341003, 'num_leaves': 109, 'feature_fraction': 0.8894782296347783, 'bagging_fraction': 0.7539222410828217, 'bagging_freq': 1, 'min_child_samples': 51}. Best is trial 6 with value: 0.9098125689084895.
# [I 2022-01-14 13:12:29,299] Trial 25 finished with value: 0.9108048511576626 and parameters: {'lambda_l1': 0.005732554665666736, 'lambda_l2': 0.00036321339540842967, 'num_leaves': 106, 'feature_fraction': 0.7753981498326598, 'bagging_fraction': 0.6337564757802275, 'bagging_freq': 1, 'min_child_samples': 21}. Best is trial 25 with value: 0.9108048511576626.
# [I 2022-01-14 13:12:30,515] Trial 26 finished with value: 0.9084895259095921 and parameters: {'lambda_l1': 0.00040944933139005373, 'lambda_l2': 0.0004439758401401281, 'num_leaves': 60, 'feature_fraction': 0.7971216852632087, 'bagging_fraction': 0.9420483851657407, 'bagging_freq': 2, 'min_child_samples': 17}. Best is trial 25 with value: 0.9108048511576626.
# [I 2022-01-14 13:12:32,139] Trial 27 finished with value: 0.9089305402425579 and parameters: {'lambda_l1': 0.01857004811382403, 'lambda_l2': 1.5550520377407426e-05, 'num_leaves': 143, 'feature_fraction': 0.8762417995431555, 'bagging_fraction': 0.8072556970185453, 'bagging_freq': 1, 'min_child_samples': 6}. Best is trial 25 with value: 0.9108048511576626.
# [I 2022-01-14 13:12:33,655] Trial 28 finished with value: 0.9037486218302094 and parameters: {'lambda_l1': 0.0003094368232925395, 'lambda_l2': 0.008423019735842115, 'num_leaves': 184, 'feature_fraction': 0.761257454980812, 'bagging_fraction': 0.5263959977920069, 'bagging_freq': 1, 'min_child_samples': 32}. Best is trial 25 with value: 0.9108048511576626.
# [I 2022-01-14 13:12:34,790] Trial 29 finished with value: 0.9132304299889746 and parameters: {'lambda_l1': 9.743675632171556e-05, 'lambda_l2': 0.00033741245899889313, 'num_leaves': 52, 'feature_fraction': 0.9380439235507275, 'bagging_fraction': 0.8331829588603831, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:35,979] Trial 30 finished with value: 0.9124586549062844 and parameters: {'lambda_l1': 0.006078933722570434, 'lambda_l2': 0.0003438005440809527, 'num_leaves': 46, 'feature_fraction': 0.9536628516791508, 'bagging_fraction': 0.832164683530367, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:37,165] Trial 31 finished with value: 0.9117971334068358 and parameters: {'lambda_l1': 0.00539284336349921, 'lambda_l2': 2.3544979562449933e-05, 'num_leaves': 56, 'feature_fraction': 0.9996527298290421, 'bagging_fraction': 0.8473895801299937, 'bagging_freq': 3, 'min_child_samples': 23}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:38,324] Trial 32 finished with value: 0.9122381477398015 and parameters: {'lambda_l1': 0.007234338203219547, 'lambda_l2': 1.8190598660761284e-05, 'num_leaves': 46, 'feature_fraction': 0.9661727529588954, 'bagging_fraction': 0.8641206556971449, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:39,518] Trial 33 finished with value: 0.9120176405733186 and parameters: {'lambda_l1': 0.0070990794672725205, 'lambda_l2': 1.2091380759432081e-05, 'num_leaves': 47, 'feature_fraction': 0.9950469756530456, 'bagging_fraction': 0.8576554881962877, 'bagging_freq': 3, 'min_child_samples': 26}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:40,657] Trial 34 finished with value: 0.9112458654906285 and parameters: {'lambda_l1': 0.09431113050130788, 'lambda_l2': 9.665565434117107e-06, 'num_leaves': 37, 'feature_fraction': 0.9480774366409207, 'bagging_fraction': 0.9126445985513103, 'bagging_freq': 3, 'min_child_samples': 27}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:41,920] Trial 35 finished with value: 0.9120176405733186 and parameters: {'lambda_l1': 5.87504431827339e-05, 'lambda_l2': 2.3335619533676382e-07, 'num_leaves': 41, 'feature_fraction': 0.9510629722828069, 'bagging_fraction': 0.9838097210181378, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:42,797] Trial 36 finished with value: 0.8997794928335171 and parameters: {'lambda_l1': 8.509825766312534e-05, 'lambda_l2': 9.690797687854408e-08, 'num_leaves': 6, 'feature_fraction': 0.9363191300067328, 'bagging_fraction': 0.9814795724907281, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:44,988] Trial 37 finished with value: 0.9057331863285557 and parameters: {'lambda_l1': 3.023894589575077e-05, 'lambda_l2': 1.8986246312009183e-08, 'num_leaves': 295, 'feature_fraction': 0.8601272633138153, 'bagging_fraction': 0.9423751882058261, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:46,149] Trial 38 finished with value: 0.911135611907387 and parameters: {'lambda_l1': 1.8249826882390813e-05, 'lambda_l2': 4.466895143682636e-07, 'num_leaves': 36, 'feature_fraction': 0.9255877485774899, 'bagging_fraction': 0.8928512306213117, 'bagging_freq': 4, 'min_child_samples': 1}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:46,692] Trial 39 finished with value: 0.7961411245865491 and parameters: {'lambda_l1': 0.00012176790882856572, 'lambda_l2': 6.031698722848864e-08, 'num_leaves': 2, 'feature_fraction': 0.83767560445905, 'bagging_fraction': 0.8174595325721857, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:47,629] Trial 40 finished with value: 0.9078280044101433 and parameters: {'lambda_l1': 0.0008290538075152968, 'lambda_l2': 7.994679644211726e-07, 'num_leaves': 76, 'feature_fraction': 0.3045458279121749, 'bagging_fraction': 0.9863715657805843, 'bagging_freq': 11, 'min_child_samples': 37}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:48,986] Trial 41 finished with value: 0.9132304299889746 and parameters: {'lambda_l1': 0.005192262760906244, 'lambda_l2': 3.813381020828382e-06, 'num_leaves': 41, 'feature_fraction': 0.9746314362138988, 'bagging_fraction': 0.8600514313174445, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:50,373] Trial 42 finished with value: 0.9124586549062844 and parameters: {'lambda_l1': 0.005488674049396614, 'lambda_l2': 3.632852751991513e-06, 'num_leaves': 55, 'feature_fraction': 0.995901004071614, 'bagging_fraction': 0.8541421063275121, 'bagging_freq': 2, 'min_child_samples': 28}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:51,558] Trial 43 finished with value: 0.9113561190738699 and parameters: {'lambda_l1': 0.012677478906397716, 'lambda_l2': 3.5323965828510868e-06, 'num_leaves': 30, 'feature_fraction': 0.9525541458556619, 'bagging_fraction': 0.7942791903819749, 'bagging_freq': 15, 'min_child_samples': 29}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:53,062] Trial 44 finished with value: 0.9094818081587651 and parameters: {'lambda_l1': 0.07846132918708304, 'lambda_l2': 4.696717238668715e-06, 'num_leaves': 79, 'feature_fraction': 0.8663170645716537, 'bagging_fraction': 0.8670966596426335, 'bagging_freq': 2, 'min_child_samples': 16}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:54,770] Trial 45 finished with value: 0.9124586549062844 and parameters: {'lambda_l1': 0.0038154061824179466, 'lambda_l2': 4.6543639936353947e-05, 'num_leaves': 135, 'feature_fraction': 0.9908620210696086, 'bagging_fraction': 0.7469908398173334, 'bagging_freq': 6, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:56,178] Trial 46 finished with value: 0.9127894156560088 and parameters: {'lambda_l1': 0.002864176586079237, 'lambda_l2': 4.872265232803455e-05, 'num_leaves': 132, 'feature_fraction': 0.9971374652530576, 'bagging_fraction': 0.7451836727205855, 'bagging_freq': 6, 'min_child_samples': 32}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:57,478] Trial 47 finished with value: 0.9100330760749724 and parameters: {'lambda_l1': 0.002534174360309818, 'lambda_l2': 5.0121605533503964e-05, 'num_leaves': 135, 'feature_fraction': 0.910674362643801, 'bagging_fraction': 0.7524062196129058, 'bagging_freq': 8, 'min_child_samples': 32}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:12:58,414] Trial 48 finished with value: 0.906284454244763 and parameters: {'lambda_l1': 0.0006008551504631311, 'lambda_l2': 0.00022362119101321598, 'num_leaves': 201, 'feature_fraction': 0.9994174735812157, 'bagging_fraction': 0.10203615488084256, 'bagging_freq': 6, 'min_child_samples': 41}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:00,150] Trial 49 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 0.0028228270273096168, 'lambda_l2': 1.536568200717539e-06, 'num_leaves': 153, 'feature_fraction': 0.8346358776787071, 'bagging_fraction': 0.6651285809684052, 'bagging_freq': 8, 'min_child_samples': 46}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:01,337] Trial 50 finished with value: 0.9044101433296582 and parameters: {'lambda_l1': 0.0002053126256747069, 'lambda_l2': 0.0015265655602138212, 'num_leaves': 103, 'feature_fraction': 0.43947406575990056, 'bagging_fraction': 0.5799007727871618, 'bagging_freq': 4, 'min_child_samples': 36}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:02,892] Trial 51 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 0.04435246603505295, 'lambda_l2': 3.635959143731541e-05, 'num_leaves': 124, 'feature_fraction': 0.9236678947784241, 'bagging_fraction': 0.7340609982072757, 'bagging_freq': 5, 'min_child_samples': 21}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:03,890] Trial 52 finished with value: 0.9094818081587651 and parameters: {'lambda_l1': 0.0028516403921837862, 'lambda_l2': 0.00016291393139965734, 'num_leaves': 25, 'feature_fraction': 0.9563410144392618, 'bagging_fraction': 0.8323449539614006, 'bagging_freq': 6, 'min_child_samples': 30}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:05,352] Trial 53 finished with value: 0.9089305402425579 and parameters: {'lambda_l1': 0.0010430698074220248, 'lambda_l2': 0.0005246313779684711, 'num_leaves': 71, 'feature_fraction': 0.8826113728470169, 'bagging_fraction': 0.7804580804394967, 'bagging_freq': 7, 'min_child_samples': 16}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:06,989] Trial 54 finished with value: 0.9103638368246968 and parameters: {'lambda_l1': 0.016341011014709767, 'lambda_l2': 6.449914490816968e-06, 'num_leaves': 95, 'feature_fraction': 0.9759664375751195, 'bagging_fraction': 0.9140301057179138, 'bagging_freq': 2, 'min_child_samples': 26}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:08,304] Trial 55 finished with value: 0.9103638368246968 and parameters: {'lambda_l1': 0.1415092441920952, 'lambda_l2': 0.00011981140462732577, 'num_leaves': 64, 'feature_fraction': 0.9184581482829182, 'bagging_fraction': 0.8218994983330657, 'bagging_freq': 5, 'min_child_samples': 40}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:10,185] Trial 56 finished with value: 0.9091510474090408 and parameters: {'lambda_l1': 0.0016465478500611488, 'lambda_l2': 0.0009104181935043498, 'num_leaves': 168, 'feature_fraction': 0.9976369572552232, 'bagging_fraction': 0.9374748583386076, 'bagging_freq': 4, 'min_child_samples': 20}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:11,618] Trial 57 finished with value: 0.9071664829106946 and parameters: {'lambda_l1': 0.032225216780867844, 'lambda_l2': 0.004178061438933893, 'num_leaves': 117, 'feature_fraction': 0.8166595985012516, 'bagging_fraction': 0.6744457995923006, 'bagging_freq': 2, 'min_child_samples': 34}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:13,642] Trial 58 finished with value: 0.906284454244763 and parameters: {'lambda_l1': 0.010980875063157215, 'lambda_l2': 3.0410051462556545e-05, 'num_leaves': 279, 'feature_fraction': 0.8967039002975793, 'bagging_fraction': 0.7712801881287713, 'bagging_freq': 12, 'min_child_samples': 28}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:15,401] Trial 59 finished with value: 0.907276736493936 and parameters: {'lambda_l1': 0.0034483483167466683, 'lambda_l2': 6.876858457275265e-05, 'num_leaves': 220, 'feature_fraction': 0.9679156672978444, 'bagging_fraction': 0.7353121618932437, 'bagging_freq': 9, 'min_child_samples': 14}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:16,246] Trial 60 finished with value: 0.902425578831312 and parameters: {'lambda_l1': 8.353504474738226e-06, 'lambda_l2': 2.168535604169113e-06, 'num_leaves': 16, 'feature_fraction': 0.6386611572571168, 'bagging_fraction': 0.8983875418499899, 'bagging_freq': 6, 'min_child_samples': 23}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:17,462] Trial 61 finished with value: 0.9100330760749724 and parameters: {'lambda_l1': 0.0068528584418796595, 'lambda_l2': 6.937494670562895e-06, 'num_leaves': 55, 'feature_fraction': 0.9639704991725725, 'bagging_fraction': 0.8649361907285618, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:19,704] Trial 62 finished with value: 0.9052921719955899 and parameters: {'lambda_l1': 0.0005696389498195125, 'lambda_l2': 1.9011754955305842e-05, 'num_leaves': 334, 'feature_fraction': 0.9366095447792746, 'bagging_fraction': 0.8760053980157715, 'bagging_freq': 4, 'min_child_samples': 32}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:20,701] Trial 63 finished with value: 0.9112458654906285 and parameters: {'lambda_l1': 0.023103887749692166, 'lambda_l2': 0.00031362904820989295, 'num_leaves': 22, 'feature_fraction': 0.9699570737368113, 'bagging_fraction': 0.8356536554716998, 'bagging_freq': 5, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:22,019] Trial 64 finished with value: 0.9092613009922822 and parameters: {'lambda_l1': 0.0001540329615367258, 'lambda_l2': 9.684100346694236e-07, 'num_leaves': 89, 'feature_fraction': 0.8995686666145309, 'bagging_fraction': 0.8062849551996478, 'bagging_freq': 2, 'min_child_samples': 17}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:24,223] Trial 65 finished with value: 0.905071664829107 and parameters: {'lambda_l1': 0.001827441246962759, 'lambda_l2': 7.101211007002383e-05, 'num_leaves': 389, 'feature_fraction': 0.8771417613132673, 'bagging_fraction': 0.7078712606941402, 'bagging_freq': 0, 'min_child_samples': 13}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:25,036] Trial 66 finished with value: 0.9056229327453142 and parameters: {'lambda_l1': 0.010744600801562976, 'lambda_l2': 0.0009127751503865142, 'num_leaves': 48, 'feature_fraction': 0.5139049349191807, 'bagging_fraction': 0.41625942598211424, 'bagging_freq': 1, 'min_child_samples': 19}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:26,458] Trial 67 finished with value: 0.9109151047409041 and parameters: {'lambda_l1': 0.003940664404740736, 'lambda_l2': 1.2418346418533692e-05, 'num_leaves': 84, 'feature_fraction': 0.9335712060800729, 'bagging_fraction': 0.9554898450052073, 'bagging_freq': 4, 'min_child_samples': 6}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:27,770] Trial 68 finished with value: 0.9114663726571114 and parameters: {'lambda_l1': 0.3090996760008378, 'lambda_l2': 4.0061172258112195e-05, 'num_leaves': 66, 'feature_fraction': 0.9775647866029687, 'bagging_fraction': 0.8837520177327745, 'bagging_freq': 2, 'min_child_samples': 39}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:29,320] Trial 69 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 0.063496319216038, 'lambda_l2': 0.00022705431855557016, 'num_leaves': 129, 'feature_fraction': 0.915633551510327, 'bagging_fraction': 0.7841577401901497, 'bagging_freq': 3, 'min_child_samples': 34}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:30,765] Trial 70 finished with value: 0.9105843439911797 and parameters: {'lambda_l1': 0.0008897624666175717, 'lambda_l2': 3.866744935188677e-06, 'num_leaves': 102, 'feature_fraction': 0.9989522337093919, 'bagging_fraction': 0.6574671170980871, 'bagging_freq': 7, 'min_child_samples': 96}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:31,947] Trial 71 finished with value: 0.911135611907387 and parameters: {'lambda_l1': 0.0065168497536271216, 'lambda_l2': 9.7143850592315e-06, 'num_leaves': 46, 'feature_fraction': 0.9400198291127627, 'bagging_fraction': 0.8360430389985308, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:33,054] Trial 72 finished with value: 0.9098125689084895 and parameters: {'lambda_l1': 4.4711439622547526e-05, 'lambda_l2': 2.2897179961114886e-07, 'num_leaves': 29, 'feature_fraction': 0.8568344760910862, 'bagging_fraction': 0.9664559493932592, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:34,267] Trial 73 finished with value: 0.9117971334068358 and parameters: {'lambda_l1': 1.4431907330115539e-05, 'lambda_l2': 1.9207722282843707e-07, 'num_leaves': 37, 'feature_fraction': 0.9494030354675487, 'bagging_fraction': 0.9297737692023204, 'bagging_freq': 3, 'min_child_samples': 30}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:35,078] Trial 74 finished with value: 0.874090407938258 and parameters: {'lambda_l1': 5.5906586482468895e-05, 'lambda_l2': 4.427972187367661e-08, 'num_leaves': 3, 'feature_fraction': 0.9727773449964094, 'bagging_fraction': 0.9951895640953436, 'bagging_freq': 1, 'min_child_samples': 44}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:36,311] Trial 75 finished with value: 0.9116868798235943 and parameters: {'lambda_l1': 0.008690027323952703, 'lambda_l2': 2.4196447283921923e-05, 'num_leaves': 57, 'feature_fraction': 0.9818386683681669, 'bagging_fraction': 0.8528635206228401, 'bagging_freq': 2, 'min_child_samples': 28}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:37,416] Trial 76 finished with value: 0.9082690187431092 and parameters: {'lambda_l1': 2.756640803031801e-06, 'lambda_l2': 0.0001388643877060675, 'num_leaves': 44, 'feature_fraction': 0.7409443480682865, 'bagging_fraction': 0.9078946799427677, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:38,353] Trial 77 finished with value: 0.9063947078280045 and parameters: {'lambda_l1': 0.0005145499522707428, 'lambda_l2': 5.546697641071773e-07, 'num_leaves': 77, 'feature_fraction': 0.3530941856762734, 'bagging_fraction': 0.7276501915731995, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:39,919] Trial 78 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 9.150234589830795e-05, 'lambda_l2': 1.4538197584577614e-06, 'num_leaves': 148, 'feature_fraction': 0.8097566097202559, 'bagging_fraction': 0.816161976319356, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:40,535] Trial 79 finished with value: 0.9060639470782801 and parameters: {'lambda_l1': 0.004891360556761185, 'lambda_l2': 1.548512552154442e-05, 'num_leaves': 16, 'feature_fraction': 0.12158632947536546, 'bagging_fraction': 0.7717035495617759, 'bagging_freq': 1, 'min_child_samples': 19}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:41,441] Trial 80 finished with value: 0.9082690187431092 and parameters: {'lambda_l1': 2.1528332282315047e-05, 'lambda_l2': 2.607592730880863e-06, 'num_leaves': 94, 'feature_fraction': 0.19311611954373892, 'bagging_fraction': 0.8852857603819202, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:42,600] Trial 81 finished with value: 0.9116868798235943 and parameters: {'lambda_l1': 0.0020222308549360697, 'lambda_l2': 8.460744333246235e-05, 'num_leaves': 44, 'feature_fraction': 0.9409942573071998, 'bagging_fraction': 0.8477325872500645, 'bagging_freq': 3, 'min_child_samples': 26}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:43,909] Trial 82 finished with value: 0.909702315325248 and parameters: {'lambda_l1': 0.01910895440229087, 'lambda_l2': 6.6627730081371875e-06, 'num_leaves': 66, 'feature_fraction': 0.9971054114812617, 'bagging_fraction': 0.9222193750227604, 'bagging_freq': 2, 'min_child_samples': 31}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:45,062] Trial 83 finished with value: 0.9079382579933848 and parameters: {'lambda_l1': 0.045662781479037746, 'lambda_l2': 0.0005151069415787219, 'num_leaves': 114, 'feature_fraction': 0.9555034976282782, 'bagging_fraction': 0.317858462773568, 'bagging_freq': 3, 'min_child_samples': 23}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:46,092] Trial 84 finished with value: 0.9078280044101433 and parameters: {'lambda_l1': 0.0013150929714661002, 'lambda_l2': 4.374890878719008e-05, 'num_leaves': 28, 'feature_fraction': 0.9063895085911362, 'bagging_fraction': 0.8000844602878643, 'bagging_freq': 5, 'min_child_samples': 36}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:47,339] Trial 85 finished with value: 0.9120176405733186 and parameters: {'lambda_l1': 0.0002628086718088803, 'lambda_l2': 2.6664070779218645e-05, 'num_leaves': 53, 'feature_fraction': 0.8862697295378388, 'bagging_fraction': 0.9633045082536954, 'bagging_freq': 6, 'min_child_samples': 18}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:49,123] Trial 86 finished with value: 0.9100330760749724 and parameters: {'lambda_l1': 0.0044441949356726785, 'lambda_l2': 0.00023910469612842977, 'num_leaves': 182, 'feature_fraction': 0.9797864550424686, 'bagging_fraction': 0.8676482809546099, 'bagging_freq': 4, 'min_child_samples': 28}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:50,279] Trial 87 finished with value: 0.9104740904079383 and parameters: {'lambda_l1': 0.014160301977436658, 'lambda_l2': 0.002515821482079533, 'num_leaves': 73, 'feature_fraction': 0.9226846909429453, 'bagging_fraction': 0.7535390419966123, 'bagging_freq': 8, 'min_child_samples': 21}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:51,492] Trial 88 finished with value: 0.9106945975744212 and parameters: {'lambda_l1': 0.0003291416400095543, 'lambda_l2': 1.1415530858354003e-05, 'num_leaves': 55, 'feature_fraction': 0.8551882321347725, 'bagging_fraction': 0.9600027154945407, 'bagging_freq': 6, 'min_child_samples': 18}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:52,564] Trial 89 finished with value: 0.9061742006615215 and parameters: {'lambda_l1': 6.256437870143252e-05, 'lambda_l2': 2.6906108338644543e-05, 'num_leaves': 15, 'feature_fraction': 0.8923041353377003, 'bagging_fraction': 0.9788299715638407, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:53,756] Trial 90 finished with value: 0.9100330760749724 and parameters: {'lambda_l1': 0.0001849977441115427, 'lambda_l2': 1.343775967049427e-08, 'num_leaves': 85, 'feature_fraction': 0.9528833908136143, 'bagging_fraction': 0.48306457772538236, 'bagging_freq': 6, 'min_child_samples': 4}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:55,197] Trial 91 finished with value: 0.9127894156560088 and parameters: {'lambda_l1': 0.03217244057625453, 'lambda_l2': 5.012242734933017e-05, 'num_leaves': 38, 'feature_fraction': 0.999777155402316, 'bagging_fraction': 0.9476472961305482, 'bagging_freq': 2, 'min_child_samples': 22}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:56,505] Trial 92 finished with value: 0.9114663726571114 and parameters: {'lambda_l1': 0.026174419595208498, 'lambda_l2': 5.679400071696387e-05, 'num_leaves': 36, 'feature_fraction': 0.9613674667114591, 'bagging_fraction': 0.9439382980823867, 'bagging_freq': 2, 'min_child_samples': 23}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:57,778] Trial 93 finished with value: 0.9098125689084895 and parameters: {'lambda_l1': 2.8779004987675356e-05, 'lambda_l2': 0.00011525904037012572, 'num_leaves': 54, 'feature_fraction': 0.9249726837661744, 'bagging_fraction': 0.9051279308049602, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:58,815] Trial 94 finished with value: 0.9070562293274531 and parameters: {'lambda_l1': 0.007929329374065252, 'lambda_l2': 2.1322815004982114e-06, 'num_leaves': 12, 'feature_fraction': 0.9994460015849997, 'bagging_fraction': 0.8502600619852753, 'bagging_freq': 2, 'min_child_samples': 26}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:13:59,993] Trial 95 finished with value: 0.91212789415656 and parameters: {'lambda_l1': 0.002297853826724662, 'lambda_l2': 4.895655200827048e-06, 'num_leaves': 28, 'feature_fraction': 0.9737647697535075, 'bagging_fraction': 0.8905005571742951, 'bagging_freq': 1, 'min_child_samples': 29}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:01,025] Trial 96 finished with value: 0.9114663726571114 and parameters: {'lambda_l1': 0.0026547700983759162, 'lambda_l2': 0.00016564004850013497, 'num_leaves': 24, 'feature_fraction': 0.9774741333531503, 'bagging_fraction': 0.8925333163373187, 'bagging_freq': 0, 'min_child_samples': 33}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:02,402] Trial 97 finished with value: 0.9095920617420066 and parameters: {'lambda_l1': 0.010342420112623825, 'lambda_l2': 5.878098590305259e-06, 'num_leaves': 70, 'feature_fraction': 0.9821136638435588, 'bagging_fraction': 0.8215802628070293, 'bagging_freq': 1, 'min_child_samples': 29}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:03,514] Trial 98 finished with value: 0.9067254685777287 and parameters: {'lambda_l1': 0.003916519936979439, 'lambda_l2': 2.786071523087344e-07, 'num_leaves': 41, 'feature_fraction': 0.672778618577341, 'bagging_fraction': 0.9353456939439051, 'bagging_freq': 10, 'min_child_samples': 57}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:05,071] Trial 99 finished with value: 0.9092613009922822 and parameters: {'lambda_l1': 0.11794021836015636, 'lambda_l2': 0.0006748665728065575, 'num_leaves': 102, 'feature_fraction': 0.9425460452942195, 'bagging_fraction': 0.5998850355062721, 'bagging_freq': 1, 'min_child_samples': 38}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:08,099] Trial 100 finished with value: 0.9016538037486218 and parameters: {'lambda_l1': 0.038414728369006265, 'lambda_l2': 4.067218474491568e-06, 'num_leaves': 482, 'feature_fraction': 0.9120804509843292, 'bagging_fraction': 0.8707747484363365, 'bagging_freq': 2, 'min_child_samples': 22}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:09,351] Trial 101 finished with value: 0.9102535832414553 and parameters: {'lambda_l1': 0.0008526385075783792, 'lambda_l2': 1.706283860975163e-05, 'num_leaves': 31, 'feature_fraction': 0.884049519649967, 'bagging_fraction': 0.9663612055333123, 'bagging_freq': 3, 'min_child_samples': 48}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:10,643] Trial 102 finished with value: 0.9104740904079383 and parameters: {'lambda_l1': 0.00553207727699793, 'lambda_l2': 3.66596289670166e-05, 'num_leaves': 61, 'feature_fraction': 0.964728626034963, 'bagging_fraction': 0.9234809045259852, 'bagging_freq': 0, 'min_child_samples': 25}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:11,960] Trial 103 finished with value: 0.9114663726571114 and parameters: {'lambda_l1': 0.0012772738872761937, 'lambda_l2': 1.0392077237352734e-05, 'num_leaves': 50, 'feature_fraction': 0.9885567170900261, 'bagging_fraction': 0.7966845070074028, 'bagging_freq': 4, 'min_child_samples': 19}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:12,732] Trial 104 finished with value: 0.8947078280044102 and parameters: {'lambda_l1': 0.01626552720018214, 'lambda_l2': 2.8999689337035634e-06, 'num_leaves': 4, 'feature_fraction': 0.9496737775966285, 'bagging_fraction': 0.8410421402105219, 'bagging_freq': 3, 'min_child_samples': 27}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:13,909] Trial 105 finished with value: 0.9088202866593165 and parameters: {'lambda_l1': 0.0022934259316105803, 'lambda_l2': 8.950464513985637e-05, 'num_leaves': 23, 'feature_fraction': 0.8713092039258599, 'bagging_fraction': 0.997478283505016, 'bagging_freq': 5, 'min_child_samples': 35}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:15,909] Trial 106 finished with value: 0.9076074972436604 and parameters: {'lambda_l1': 0.0002712630167403756, 'lambda_l2': 1.3267611137494125e-07, 'num_leaves': 210, 'feature_fraction': 0.9271285471700628, 'bagging_fraction': 0.9077152402670292, 'bagging_freq': 1, 'min_child_samples': 17}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:17,874] Trial 107 finished with value: 0.9076074972436604 and parameters: {'lambda_l1': 0.00778001164898284, 'lambda_l2': 7.957101090245197e-06, 'num_leaves': 270, 'feature_fraction': 0.9654399971883885, 'bagging_fraction': 0.6888425749620062, 'bagging_freq': 2, 'min_child_samples': 31}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:19,113] Trial 108 finished with value: 0.9051819184123484 and parameters: {'lambda_l1': 0.001521439233779141, 'lambda_l2': 2.1910326018118587e-05, 'num_leaves': 79, 'feature_fraction': 0.5944127367799599, 'bagging_fraction': 0.8808141969202905, 'bagging_freq': 4, 'min_child_samples': 25}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:20,318] Trial 109 finished with value: 0.9103638368246968 and parameters: {'lambda_l1': 0.18654112245902124, 'lambda_l2': 6.579460133033244e-07, 'num_leaves': 38, 'feature_fraction': 0.9830213508406518, 'bagging_fraction': 0.8518907944943276, 'bagging_freq': 2, 'min_child_samples': 67}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:22,168] Trial 110 finished with value: 0.911135611907387 and parameters: {'lambda_l1': 0.003544944501402307, 'lambda_l2': 0.0003143783698424744, 'num_leaves': 235, 'feature_fraction': 0.9046785248846929, 'bagging_fraction': 0.8291039971013767, 'bagging_freq': 7, 'min_child_samples': 22}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:23,396] Trial 111 finished with value: 0.9101433296582139 and parameters: {'lambda_l1': 0.00010855808816868359, 'lambda_l2': 5.08864897939931e-06, 'num_leaves': 51, 'feature_fraction': 0.9373455943055797, 'bagging_fraction': 0.951757880637373, 'bagging_freq': 3, 'min_child_samples': 29}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:24,785] Trial 112 finished with value: 0.909922822491731 and parameters: {'lambda_l1': 0.05692566901679151, 'lambda_l2': 5.353451515282669e-05, 'num_leaves': 64, 'feature_fraction': 0.9551148665973036, 'bagging_fraction': 0.9703712849258699, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:25,809] Trial 113 finished with value: 0.9077177508269019 and parameters: {'lambda_l1': 0.00043787324849025905, 'lambda_l2': 1.5442498200145637e-05, 'num_leaves': 16, 'feature_fraction': 0.9845479596151645, 'bagging_fraction': 0.8937332735768239, 'bagging_freq': 2, 'min_child_samples': 27}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:27,198] Trial 114 finished with value: 0.9126791620727673 and parameters: {'lambda_l1': 0.0007249489426980884, 'lambda_l2': 1.308526569470268e-06, 'num_leaves': 92, 'feature_fraction': 0.996618787135214, 'bagging_fraction': 0.9244257031298253, 'bagging_freq': 4, 'min_child_samples': 20}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:28,577] Trial 115 finished with value: 0.909922822491731 and parameters: {'lambda_l1': 0.0007810800456419474, 'lambda_l2': 1.255526565053182e-06, 'num_leaves': 92, 'feature_fraction': 0.9656423723058003, 'bagging_fraction': 0.9236609007133896, 'bagging_freq': 4, 'min_child_samples': 19}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:30,122] Trial 116 finished with value: 0.9106945975744212 and parameters: {'lambda_l1': 0.002732177850778178, 'lambda_l2': 3.119850649668893e-05, 'num_leaves': 132, 'feature_fraction': 0.9977450500091772, 'bagging_fraction': 0.8624638644820177, 'bagging_freq': 5, 'min_child_samples': 20}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:31,662] Trial 117 finished with value: 0.909922822491731 and parameters: {'lambda_l1': 0.005851924420505319, 'lambda_l2': 1.691724246447167e-06, 'num_leaves': 155, 'feature_fraction': 0.9295105601428726, 'bagging_fraction': 0.772021597700434, 'bagging_freq': 6, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:33,171] Trial 118 finished with value: 0.9101433296582139 and parameters: {'lambda_l1': 0.013048487427560476, 'lambda_l2': 3.4687203932291264e-07, 'num_leaves': 117, 'feature_fraction': 0.9466799065568587, 'bagging_fraction': 0.7917718885312284, 'bagging_freq': 3, 'min_child_samples': 42}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:34,408] Trial 119 finished with value: 0.9126791620727673 and parameters: {'lambda_l1': 0.0006599965737972119, 'lambda_l2': 3.2580952553556133e-06, 'num_leaves': 73, 'feature_fraction': 0.9989650025518035, 'bagging_fraction': 0.8196736306690225, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:35,891] Trial 120 finished with value: 0.9095920617420066 and parameters: {'lambda_l1': 0.0005786990801561109, 'lambda_l2': 9.541491561234014e-07, 'num_leaves': 108, 'feature_fraction': 0.9992603268825424, 'bagging_fraction': 0.8102916104086187, 'bagging_freq': 4, 'min_child_samples': 14}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:37,173] Trial 121 finished with value: 0.9106945975744212 and parameters: {'lambda_l1': 0.0022324931910519, 'lambda_l2': 3.1466489194911162e-06, 'num_leaves': 69, 'feature_fraction': 0.9724487623876537, 'bagging_fraction': 0.8720715655517386, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:38,497] Trial 122 finished with value: 0.9113561190738699 and parameters: {'lambda_l1': 0.0012293468503801295, 'lambda_l2': 4.9451888911510685e-06, 'num_leaves': 80, 'feature_fraction': 0.9829020725366945, 'bagging_fraction': 0.8270321079194811, 'bagging_freq': 5, 'min_child_samples': 17}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:39,811] Trial 123 finished with value: 0.9110253583241456 and parameters: {'lambda_l1': 0.003901165031026417, 'lambda_l2': 1.8850880233402273e-06, 'num_leaves': 43, 'feature_fraction': 0.9596270212146679, 'bagging_fraction': 0.7321964817681859, 'bagging_freq': 4, 'min_child_samples': 30}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:41,039] Trial 124 finished with value: 0.9104740904079383 and parameters: {'lambda_l1': 0.00014089733982210946, 'lambda_l2': 9.624415939903184e-06, 'num_leaves': 27, 'feature_fraction': 0.9455283056290961, 'bagging_fraction': 0.8982298533659628, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:42,314] Trial 125 finished with value: 0.9112458654906285 and parameters: {'lambda_l1': 0.00022859667309979253, 'lambda_l2': 2.224740060154739e-05, 'num_leaves': 57, 'feature_fraction': 0.9178522373221423, 'bagging_fraction': 0.8550079319676306, 'bagging_freq': 2, 'min_child_samples': 27}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:43,919] Trial 126 finished with value: 0.9109151047409041 and parameters: {'lambda_l1': 0.022862832423949833, 'lambda_l2': 7.122267254010966e-08, 'num_leaves': 92, 'feature_fraction': 0.9996269351187965, 'bagging_fraction': 0.7538846314092521, 'bagging_freq': 3, 'min_child_samples': 33}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:45,120] Trial 127 finished with value: 0.9122381477398015 and parameters: {'lambda_l1': 0.009091373972914287, 'lambda_l2': 0.0016174119815948187, 'num_leaves': 35, 'feature_fraction': 0.9721815500998998, 'bagging_fraction': 0.8801313910299869, 'bagging_freq': 4, 'min_child_samples': 22}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:46,343] Trial 128 finished with value: 0.9114663726571114 and parameters: {'lambda_l1': 0.010562118755103827, 'lambda_l2': 0.008251365689292297, 'num_leaves': 35, 'feature_fraction': 0.9820625563672953, 'bagging_fraction': 0.9195778847865962, 'bagging_freq': 1, 'min_child_samples': 13}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:47,511] Trial 129 finished with value: 0.9112458654906285 and parameters: {'lambda_l1': 0.0003403182964972124, 'lambda_l2': 0.0012626302727968314, 'num_leaves': 64, 'feature_fraction': 0.9048221121033676, 'bagging_fraction': 0.8910826904732864, 'bagging_freq': 4, 'min_child_samples': 16}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:48,647] Trial 130 finished with value: 0.9071664829106946 and parameters: {'lambda_l1': 0.001647353525682723, 'lambda_l2': 0.0001966970071210504, 'num_leaves': 13, 'feature_fraction': 0.9352028784465325, 'bagging_fraction': 0.9431132766074763, 'bagging_freq': 5, 'min_child_samples': 8}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:49,907] Trial 131 finished with value: 0.9119073869900772 and parameters: {'lambda_l1': 0.005754550795525276, 'lambda_l2': 5.272661831908047e-05, 'num_leaves': 50, 'feature_fraction': 0.9659062210039607, 'bagging_fraction': 0.8325216234529159, 'bagging_freq': 6, 'min_child_samples': 22}. Best is trial 29 with value: 0.9132304299889746.
# [I 2022-01-14 13:14:51,291] Trial 132 finished with value: 0.9112458654906285 and parameters: {'lambda_l1': 0.007818525223110096, 'lambda_l2': 1.3857882471950431e-05, 'num_leaves': 41, 'feature_fraction': 0.9744487743730447, 'bagging_fraction': 0.8788180003538778, 'bagging_freq': 3, 'min_child_samples': 26}. Best is trial 29 with value: 0.9132304299889746.
# ...
# [I 2022-01-14 13:41:12,423] Trial 1438 finished with value: 0.907276736493936 and parameters: {'lambda_l1': 2.252242966514284e-08, 'lambda_l2': 0.2100203022041557, 'num_leaves': 41, 'feature_fraction': 0.8865429877582677, 'bagging_fraction': 0.30571022265143905, 'bagging_freq': 6, 'min_child_samples': 73}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:13,278] Trial 1439 finished with value: 0.9136714443219405 and parameters: {'lambda_l1': 1.3948343509768446e-08, 'lambda_l2': 0.06142628792860073, 'num_leaves': 35, 'feature_fraction': 0.8649383652402481, 'bagging_fraction': 0.359812884799555, 'bagging_freq': 5, 'min_child_samples': 77}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:14,289] Trial 1440 finished with value: 0.9126791620727673 and parameters: {'lambda_l1': 4.813186509134814e-08, 'lambda_l2': 0.1275456863563047, 'num_leaves': 60, 'feature_fraction': 0.9143079836139109, 'bagging_fraction': 0.3294925071101737, 'bagging_freq': 4, 'min_child_samples': 70}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:15,229] Trial 1441 finished with value: 0.9108048511576626 and parameters: {'lambda_l1': 1.1227135862300195e-08, 'lambda_l2': 0.07141536654839642, 'num_leaves': 51, 'feature_fraction': 0.8974289737413279, 'bagging_fraction': 0.35309508816613566, 'bagging_freq': 8, 'min_child_samples': 94}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:16,088] Trial 1442 finished with value: 0.9127894156560088 and parameters: {'lambda_l1': 3.3927303843340754e-08, 'lambda_l2': 0.36313154118299307, 'num_leaves': 27, 'feature_fraction': 0.8728601426872593, 'bagging_fraction': 0.40701961909910367, 'bagging_freq': 5, 'min_child_samples': 69}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:17,064] Trial 1443 finished with value: 0.9134509371554576 and parameters: {'lambda_l1': 2.3735220571397634e-08, 'lambda_l2': 0.2575538372988074, 'num_leaves': 50, 'feature_fraction': 0.8987060627123274, 'bagging_fraction': 0.3756610677101332, 'bagging_freq': 5, 'min_child_samples': 72}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:17,863] Trial 1444 finished with value: 0.9084895259095921 and parameters: {'lambda_l1': 2.4587442204180947e-08, 'lambda_l2': 0.6213796473870256, 'num_leaves': 19, 'feature_fraction': 0.823829042480674, 'bagging_fraction': 0.3460139389727882, 'bagging_freq': 6, 'min_child_samples': 80}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:18,763] Trial 1445 finished with value: 0.9080485115766262 and parameters: {'lambda_l1': 5.1744209492987e-08, 'lambda_l2': 0.35985513338813585, 'num_leaves': 10, 'feature_fraction': 0.8482063027686674, 'bagging_fraction': 0.368739636564883, 'bagging_freq': 5, 'min_child_samples': 86}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:19,708] Trial 1446 finished with value: 0.9131201764057332 and parameters: {'lambda_l1': 1.9187577141913866e-08, 'lambda_l2': 0.18463059812248703, 'num_leaves': 49, 'feature_fraction': 0.9053652485369468, 'bagging_fraction': 0.3145141789157456, 'bagging_freq': 4, 'min_child_samples': 71}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:20,765] Trial 1447 finished with value: 0.9091510474090408 and parameters: {'lambda_l1': 1.9915988930992538e-08, 'lambda_l2': 0.11356317865650481, 'num_leaves': 63, 'feature_fraction': 0.8868361781449361, 'bagging_fraction': 0.2860579447273119, 'bagging_freq': 5, 'min_child_samples': 67}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:21,728] Trial 1448 finished with value: 0.9134509371554576 and parameters: {'lambda_l1': 1.0283118427931239e-08, 'lambda_l2': 0.11508673703533721, 'num_leaves': 58, 'feature_fraction': 0.926122545296367, 'bagging_fraction': 0.3450354116709604, 'bagging_freq': 9, 'min_child_samples': 74}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:22,320] Trial 1449 finished with value: 0.896141124586549 and parameters: {'lambda_l1': 3.502216100733823e-08, 'lambda_l2': 0.5096947746432435, 'num_leaves': 38, 'feature_fraction': 0.10324352776560414, 'bagging_fraction': 0.3924824284573537, 'bagging_freq': 5, 'min_child_samples': 70}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:23,368] Trial 1450 finished with value: 0.9127894156560088 and parameters: {'lambda_l1': 1.0197759927846803e-08, 'lambda_l2': 0.24624987941987347, 'num_leaves': 68, 'feature_fraction': 0.9144078086689531, 'bagging_fraction': 0.3610245042299952, 'bagging_freq': 4, 'min_child_samples': 73}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:24,448] Trial 1451 finished with value: 0.9101433296582139 and parameters: {'lambda_l1': 6.155196542311486e-08, 'lambda_l2': 0.19299736015763685, 'num_leaves': 71, 'feature_fraction': 0.9276879180621487, 'bagging_fraction': 0.3259801935639619, 'bagging_freq': 6, 'min_child_samples': 68}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:25,442] Trial 1452 finished with value: 0.9141124586549063 and parameters: {'lambda_l1': 1.6281243062698166e-08, 'lambda_l2': 6.315036293657327e-05, 'num_leaves': 51, 'feature_fraction': 0.9084465343388345, 'bagging_fraction': 0.34523486540902837, 'bagging_freq': 5, 'min_child_samples': 71}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:26,412] Trial 1453 finished with value: 0.911135611907387 and parameters: {'lambda_l1': 2.2874294972225265e-08, 'lambda_l2': 0.16560969368162257, 'num_leaves': 45, 'feature_fraction': 0.8915335559751313, 'bagging_fraction': 0.3029505079832735, 'bagging_freq': 5, 'min_child_samples': 73}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:27,465] Trial 1454 finished with value: 0.9132304299889746 and parameters: {'lambda_l1': 1.609545192544682e-08, 'lambda_l2': 0.303592363396513, 'num_leaves': 51, 'feature_fraction': 0.9076815880061445, 'bagging_fraction': 0.33467690703994163, 'bagging_freq': 5, 'min_child_samples': 76}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:28,407] Trial 1455 finished with value: 0.9126791620727673 and parameters: {'lambda_l1': 2.0274238228131066e-08, 'lambda_l2': 6.838087391242564e-05, 'num_leaves': 35, 'feature_fraction': 0.8839409141932386, 'bagging_fraction': 0.3198170577795047, 'bagging_freq': 5, 'min_child_samples': 72}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:29,403] Trial 1456 finished with value: 0.9110253583241456 and parameters: {'lambda_l1': 1.0033209231598338e-08, 'lambda_l2': 0.0006555016355918669, 'num_leaves': 42, 'feature_fraction': 0.9029858224084494, 'bagging_fraction': 0.3485597590743338, 'bagging_freq': 6, 'min_child_samples': 76}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:30,258] Trial 1457 finished with value: 0.9100330760749724 and parameters: {'lambda_l1': 1.6399923508394492e-08, 'lambda_l2': 0.0003569289487315047, 'num_leaves': 34, 'feature_fraction': 0.8814190075582805, 'bagging_fraction': 0.30607611706118426, 'bagging_freq': 4, 'min_child_samples': 74}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:31,122] Trial 1458 finished with value: 0.9113561190738699 and parameters: {'lambda_l1': 2.863167526606463e-08, 'lambda_l2': 0.6235925752217181, 'num_leaves': 35, 'feature_fraction': 0.8591291726065411, 'bagging_fraction': 0.3368764742979639, 'bagging_freq': 5, 'min_child_samples': 71}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:32,239] Trial 1459 finished with value: 0.9106945975744212 and parameters: {'lambda_l1': 1.8924656893569998e-08, 'lambda_l2': 0.002219969319397309, 'num_leaves': 51, 'feature_fraction': 0.8994483673784219, 'bagging_fraction': 0.3414146884986535, 'bagging_freq': 6, 'min_child_samples': 71}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:33,312] Trial 1460 finished with value: 0.9115766262403528 and parameters: {'lambda_l1': 1.2891319722579028e-08, 'lambda_l2': 0.006623124550920739, 'num_leaves': 47, 'feature_fraction': 0.909752934340908, 'bagging_fraction': 0.3261949670798703, 'bagging_freq': 5, 'min_child_samples': 75}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:34,401] Trial 1461 finished with value: 0.9115766262403528 and parameters: {'lambda_l1': 1.600859235858818e-08, 'lambda_l2': 0.00010591374987471076, 'num_leaves': 56, 'feature_fraction': 0.8810525726556216, 'bagging_fraction': 0.31007726672591124, 'bagging_freq': 5, 'min_child_samples': 68}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:35,219] Trial 1462 finished with value: 0.9128996692392503 and parameters: {'lambda_l1': 1.4161022023779728e-08, 'lambda_l2': 0.05554938379968299, 'num_leaves': 27, 'feature_fraction': 0.8986964752407502, 'bagging_fraction': 0.35602652139027946, 'bagging_freq': 4, 'min_child_samples': 72}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:36,301] Trial 1463 finished with value: 0.9122381477398015 and parameters: {'lambda_l1': 2.610569085804958e-08, 'lambda_l2': 0.00024271872428169953, 'num_leaves': 58, 'feature_fraction': 0.8823962273693343, 'bagging_fraction': 0.2832819633828488, 'bagging_freq': 5, 'min_child_samples': 71}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:37,057] Trial 1464 finished with value: 0.9105843439911797 and parameters: {'lambda_l1': 4.420132973135572e-08, 'lambda_l2': 4.546532809392118e-05, 'num_leaves': 18, 'feature_fraction': 0.8539645036187913, 'bagging_fraction': 0.36079381833923935, 'bagging_freq': 4, 'min_child_samples': 67}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:38,121] Trial 1465 finished with value: 0.9115766262403528 and parameters: {'lambda_l1': 2.9324554616317226e-08, 'lambda_l2': 0.2567735038862898, 'num_leaves': 62, 'feature_fraction': 0.9200540657501579, 'bagging_fraction': 0.34286387795293166, 'bagging_freq': 6, 'min_child_samples': 69}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:39,006] Trial 1466 finished with value: 0.9106945975744212 and parameters: {'lambda_l1': 2.1484126229183137e-08, 'lambda_l2': 0.10846838578577854, 'num_leaves': 44, 'feature_fraction': 0.8770758931003912, 'bagging_fraction': 0.2505354155222428, 'bagging_freq': 5, 'min_child_samples': 78}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:39,984] Trial 1467 finished with value: 0.9119073869900772 and parameters: {'lambda_l1': 1.6458461573213105e-08, 'lambda_l2': 0.07585669756923749, 'num_leaves': 52, 'feature_fraction': 0.9197311601769255, 'bagging_fraction': 0.32550072890887605, 'bagging_freq': 5, 'min_child_samples': 74}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:41,003] Trial 1468 finished with value: 0.9134509371554576 and parameters: {'lambda_l1': 3.8278187741130645e-08, 'lambda_l2': 0.004349520973722766, 'num_leaves': 33, 'feature_fraction': 0.842704935242342, 'bagging_fraction': 0.3720018712278424, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:42,131] Trial 1469 finished with value: 0.9093715545755237 and parameters: {'lambda_l1': 8.79821416088032e-08, 'lambda_l2': 0.9720268535512664, 'num_leaves': 65, 'feature_fraction': 0.9039103395926523, 'bagging_fraction': 0.34634088746127134, 'bagging_freq': 6, 'min_child_samples': 70}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:43,221] Trial 1470 finished with value: 0.9093715545755237 and parameters: {'lambda_l1': 0.14115659037085462, 'lambda_l2': 0.7548238181441863, 'num_leaves': 41, 'feature_fraction': 0.8627622078912879, 'bagging_fraction': 0.32812309779636245, 'bagging_freq': 4, 'min_child_samples': 67}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:44,329] Trial 1471 finished with value: 0.9132304299889746 and parameters: {'lambda_l1': 2.4769041920493787e-08, 'lambda_l2': 0.14444334951757085, 'num_leaves': 54, 'feature_fraction': 0.8919815959254328, 'bagging_fraction': 0.3645559122016648, 'bagging_freq': 5, 'min_child_samples': 73}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:45,325] Trial 1472 finished with value: 0.913561190738699 and parameters: {'lambda_l1': 2.4257135104757147e-08, 'lambda_l2': 0.22229197195128944, 'num_leaves': 46, 'feature_fraction': 0.9284792455938685, 'bagging_fraction': 0.38638937764865383, 'bagging_freq': 5, 'min_child_samples': 70}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:45,991] Trial 1473 finished with value: 0.9077177508269019 and parameters: {'lambda_l1': 3.731285180706627e-08, 'lambda_l2': 0.9916068954988625, 'num_leaves': 29, 'feature_fraction': 0.7931155893470744, 'bagging_fraction': 0.11598656464201162, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:46,952] Trial 1474 finished with value: 0.9091510474090408 and parameters: {'lambda_l1': 1.6636777251673434e-08, 'lambda_l2': 0.1425484970819155, 'num_leaves': 58, 'feature_fraction': 0.8971507982997002, 'bagging_fraction': 0.30771437054233397, 'bagging_freq': 6, 'min_child_samples': 69}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:47,859] Trial 1475 finished with value: 0.9117971334068358 and parameters: {'lambda_l1': 0.005023100122925308, 'lambda_l2': 0.46385316470961, 'num_leaves': 44, 'feature_fraction': 0.9108783733491734, 'bagging_fraction': 0.3183752694112485, 'bagging_freq': 4, 'min_child_samples': 72}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:48,882] Trial 1476 finished with value: 0.9124586549062844 and parameters: {'lambda_l1': 2.6220975689759432e-08, 'lambda_l2': 0.24784736116461145, 'num_leaves': 64, 'feature_fraction': 0.9271626649776634, 'bagging_fraction': 0.3488668120714651, 'bagging_freq': 5, 'min_child_samples': 77}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:49,892] Trial 1477 finished with value: 0.9134509371554576 and parameters: {'lambda_l1': 1.302820135308673e-07, 'lambda_l2': 0.0012354326760841586, 'num_leaves': 55, 'feature_fraction': 0.876393107151039, 'bagging_fraction': 0.36476594909410054, 'bagging_freq': 5, 'min_child_samples': 75}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:50,759] Trial 1478 finished with value: 0.9104740904079383 and parameters: {'lambda_l1': 0.5605127203978152, 'lambda_l2': 0.3613970110809664, 'num_leaves': 42, 'feature_fraction': 0.9377216057293756, 'bagging_fraction': 0.2941671569361576, 'bagging_freq': 6, 'min_child_samples': 70}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:51,762] Trial 1479 finished with value: 0.9077177508269019 and parameters: {'lambda_l1': 1.0014937658707029e-08, 'lambda_l2': 0.08803788715483887, 'num_leaves': 51, 'feature_fraction': 0.7195639727238697, 'bagging_fraction': 0.32319929253983287, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 1193 with value: 0.9156560088202866.
# [I 2022-01-14 13:41:52,852] Trial 1480 finished with value: 0.9117971334068358 and parameters: {'lambda_l1': 5.982809814289531e-08, 'lambda_l2': 0.3437382056807806, 'num_leaves': 71, 'feature_fraction': 0.9185479873373489, 'bagging_fraction': 0.3864909811726197, 'bagging_freq': 4, 'min_child_samples': 68}. Best is trial 1193 with value: 0.9156560088202866.
# Number of completed trials: 1481
# Best trial:
# 	Best Score: 0.9156560088202866
# 	Best Params:
#     lambda_l1: 3.196991799709279e-08
#     lambda_l2: 0.16109706278926267
#     num_leaves: 73
#     feature_fraction: 0.9522850614891559
#     bagging_fraction: 0.3693079885451934
#     bagging_freq: 5
#     min_child_samples: 69

# %% [markdown]
# ### Model tuned

# %%
classifier = LGBMClassifier(lambda_l1=3.196991799709279e-08,
                            lambda_l2=0.16109706278926267,
                            num_leaves=73,
                            feature_fraction=0.9522850614891559,
                            bagging_fraction=0.3693079885451934,
                            bagging_freq=5,
                           min_child_samples=69)

# %%
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      9070
#            1       0.97      0.91      0.94      9070
#
#     accuracy                           0.94     18140
#    macro avg       0.94      0.94      0.94     18140
# weighted avg       0.94      0.94      0.94     18140

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Some recommendations for the campaign
#
# Person to contact in priority :
#
# >People who made a subscription on the last campaign
#
# >Student and retired
#
# >Singles
#
# Also, limit the number of contacts under 15 will optimized the efficientness of the campaign
#
# The model can be use to predict which part of a contact list can subscribed and so estimate a rentability regarding the cost of this campaign

# %%
import pickle

# %%
pickle.dump(classifier, open('bank_telemarketing.sav', 'wb'))

# %%
from IPython.display import FileLink 
FileLink('bank_telemarketing.sav')
# Out:
# C:\Users\riche\OneDrive\Bureau\Formation\Kaggle\Bank telemarketing\bank_telemarketing.sav
